# %%
import pandas as pd

# %%
df=pd.read_csv('4_done.csv',encoding='utf-8')
df
# Out:
#       Unnamed: 0      header  \
# 0           4357  2022-08-31
# 1           4358  2022-08-31
# 2           4359  2022-08-31
# 3           4360  2022-08-31
# 4           4362  2022-08-31
# ...          ...         ...
# 6173       18609  2022-06-30
# 6174       18610  2022-06-30
# 6175       18611  2022-06-30
# 6176       18613  2022-06-30
# 6177       18614  2022-06-30
#
#                                                   title  \
# 0        잘 나가는 명품 브랜드들이 왜 갑자기 SNS를 없애는 걸까? 을(를) 시청했습니다.
# 1                         [병맛더빙] 허언증갤러리 정모 을(를) 시청했습니다.
# 2                             [장삐쭈 단편선] PC 을(를) 시청했습니다.
# 3                      LCK 결승전에서 틀어준 미친 영상 을(를) 시청했습니다.
# 4                            [장삐쭈 단편선] 정류장 을(를) 시청했습니다.
# ...                                                 ...
# 6173  7R(2), #14, In Soon-i - Tea house in the winte...
# 6174  7R(2), #13, Kim Kyung-ho - Can't find the orio...
# 6175  7R(2), #12, Jo Kwan-woo - Short hair, 조관우 - 단발...
# ...

# %%
df=df.rename(columns={'Unnamed: 0':'카테고리'})
df
# Out:
#        카테고리      header                                              title  \
# 0      4357  2022-08-31     잘 나가는 명품 브랜드들이 왜 갑자기 SNS를 없애는 걸까? 을(를) 시청했습니다.
# 1      4358  2022-08-31                      [병맛더빙] 허언증갤러리 정모 을(를) 시청했습니다.
# 2      4359  2022-08-31                          [장삐쭈 단편선] PC 을(를) 시청했습니다.
# 3      4360  2022-08-31                   LCK 결승전에서 틀어준 미친 영상 을(를) 시청했습니다.
# 4      4362  2022-08-31                         [장삐쭈 단편선] 정류장 을(를) 시청했습니다.
# ...     ...         ...                                                ...
# 6173  18609  2022-06-30  7R(2), #14, In Soon-i - Tea house in the winte...
# 6174  18610  2022-06-30  7R(2), #13, Kim Kyung-ho - Can't find the orio...
# 6175  18611  2022-06-30  7R(2), #12, Jo Kwan-woo - Short hair, 조관우 - 단발...
# 6176  18613  2022-06-30    7R(2), #10, I Am A Singer 20110925 을(를) 시청했습니다.
# 6177  18614  2022-06-30  220627 coogie ins live 2 (ft. woo) 쿠기 라방 (ft. ...
#
#                                          titleUrl  subtitles  \
# ...

# %%
import requests

# %%
count=0

for i in range(0,len(df)):

    url=df['titleUrl'][i]

    r = requests.get(url.format(id="288457298900-3ft4aq3l0mft2ti1pg6nvo2im4cf43me.apps.googleusercontent.com", api_key="AIzaSyBE1eDwNBOlfotaLRpVrdMer7MizW2jOWc"))

    try:

        df['카테고리'][i]=r.text.split("category")[1].split(",")[0][3:-1]

    except:

        df['카테고리'][i]='없음'

        count+=1

print(count)

df.to_csv('4_카테고리.csv',encoding='utf-8')
# Out:
# 4
